# %%
import requests
import base64
import datetime
from urllib.parse import urlencode

# %%
class SpotifyAPI():
    access_token = None
    expires = datetime.datetime.now()
    expired = True
    client_id = None
    client_secret = None
    redirect_uri = 'http://localhost:8888/notebooks/Autho.ipynb'
    token_url = 'https://accounts.spotify.com/api/token'
    
    
    def __init__(self, client_id, client_secret):
        self.client_id = client_id
        self.client_secret = client_secret
    
    def getTokenData(self):
        return {
            'grant_type': 'client_credentials'
        }
    def getTokenHeaders(self):
        client_creds = f"{self.client_id}:{self. client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return {
            'authorization': f"Basic {client_creds_b64.decode()}" # <base64 encoded client_id:client_secret>
        }
    
    def performAuth(self):
        r = requests.post(self.token_url, data=self.getTokenData(), headers = self.getTokenHeaders())
        if r.status_code not in range(200, 299):
            return False
        response = r.json()
        now = datetime.datetime.now()
        self.access_token = response['access_token']
        expires_in = response['expires_in']
        self.expires = now + datetime.timedelta(seconds=expires_in)
        self.expired = self.expires < now
        return True

# %%
client_id = '4e75cab0012d409da502214e828ade40'
client_secret = '3a5f1a1c83f442f991b1321a4e78edac'
client = SpotifyAPI(client_id, client_secret)

# %%
client.performAuth()
# Out:
# True

# %%
headers = {
    "Authorization": f"Bearer {client.access_token}",
    "Content-Type": "application/json",
    "Accept": "application/json"
}
user_id = 'panda6722'
playlist_id = '1KHBEkNFB5qjp8slnwQ7cB'
#url = "https://api.spotify.com/v1/search"
url = f"https://api.spotify.com/v1/users/{user_id}/playlists"
# url = f"https://api.spotify.com/v1/playlists/{playlist_id}/images"
data = {
    "q": "Time",
    "type":"track"
}

# %%
r = requests.get(url, headers=headers)

# %%
r.json()
# Out:
# {'href': 'https://api.spotify.com/v1/users/panda6722/playlists?offset=0&limit=20',
#  'items': [{'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1KHBEkNFB5qjp8slnwQ7cB'},
#    'href': 'https://api.spotify.com/v1/playlists/1KHBEkNFB5qjp8slnwQ7cB',
#    'id': '1KHBEkNFB5qjp8slnwQ7cB',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000485147f930accd8ac01686401fa2ab67616d00004851dd8408b50f45c66139f44ce2ab67616d0000b273af52c228c9619ff6298b08cdab67616d0000b273c5148520a59be191eea16989',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000485147f930accd8ac01686401fa2ab67616d00004851dd8408b50f45c66139f44ce2ab67616d0000b273af52c228c9619ff6298b08cdab67616d0000b273c5148520a59be191eea16989',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000485147f930accd8ac01686401fa2ab67616d00004851dd8408b50f45c66139f44ce2ab67616d0000b273af52c228c9619ff6298b08cdab67616d0000b273c5148520a59be191eea16989',
#      'width': 60}],
#    'name': 'Climb to Glory',
#    'owner': {'display_name': 'dub!d',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/panda6722'},
#     'href': 'https://api.spotify.com/v1/users/panda6722',
#     'id': 'panda6722',
#     'type': 'user',
#     'uri': 'spotify:user:panda6722'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'OSxmNjhjMTNjZmRkNjBlNzk2ZTk1ODcxYWUxMjBlN2I4NWRjMDk5ZmMz',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1KHBEkNFB5qjp8slnwQ7cB/tracks',
#     'total': 7},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1KHBEkNFB5qjp8slnwQ7cB'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1MbwwKfk4C7Jw5Y8Ebi7V0'},
#    'href': 'https://api.spotify.com/v1/playlists/1MbwwKfk4C7Jw5Y8Ebi7V0',
#    'id': '1MbwwKfk4C7Jw5Y8Ebi7V0',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d000048512a038d3bf875d23e4aeaa84eab67616d00004

#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d00004851179c168e6a41c4cccf5ff729ab67616d00004851e20e5c366b497518353497b0ab67616d0000b2737dd8f95320e8ef08aa121dfeab67616d0000b273e20e5c366b497518353497b0',
#      'width': 60}],
#    'name': 'K-POP',
#    'owner': {'display_name': 'dub!d',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/panda6722'},
#     'href': 'https://api.spotify.com/v1/users/panda6722',
#     'id': 'panda6722',
#     'type': 'user',
#     'uri': 'spotify:user:panda6722'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'NTAsZTk0OGQxNDQzYWVjNzZlZDI3YjA2N2M5NDZmZjNhNjk3MjQ4M2ExOQ==',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/71hpnWYwNPa7vmPosCwdsN/tracks',
#     'total': 18},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:71hpnWYwNPa7vmPosCwdsN'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/1MFZQgUbFwvEgLypZxGC0w'},
#    'href': 'https://api.spotify.com/v1/playlists/1MFZQgUbFwvEgLypZxGC0w',
#    'id': '1MFZQgUbFwvEgLypZxGC0w',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706c0000bebb644ba8df76136653ee620f42',
#      'width': None}],
#    'name': 'Meet Beats',
#    'owner': {'display_name': 'dub!d',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/panda6722'},
#     'href': 'https://api.spotify.com/v1/users/panda6722',
#     'id': 'panda6722',
#     'type': 'user',
#     'uri': 'spotify:user:panda6722'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTM1LGU1OWNjN2E0YmI0YWY2MjY3Y2JhYmU3NWE0NWFiN2UxMTNjZDg1YzM=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/1MFZQgUbFwvEgLypZxGC0w/tracks',
#     'total': 21},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:1MFZQgUbFwvEgLypZxGC0w'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/3uBDLt5J36QdtVRhjfiQTH'},
#    'href': 'https://api.spotify.com/v1/playlists/3uBDLt5J36QdtVRhjfiQTH',
#    'id': '3uBDLt5J36QdtVRhjfiQTH',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000485150f9a2e8f1102e1f5a76d369ab67616d0000b2733505183cc0e24d2f7560174aab67616d0000b2734a4b92dcf7a5c51cc4f7424cab67616d0000b273660aadbda2da6b1c2dd3d1a5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000485150f9a2e8f1102e1f5a76d369ab67616d0000b2733505183cc0e24d2f7560174aab67616d0000b2734a4b92dcf7a5c51cc4f7424cab67616d0000b273660aadbda2da6b1c2dd3d1a5',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d0000485150f9a2e8f1102e1f5a76d369ab67616d0000b2733505183cc0e24d2f7560174aab67616d0000b2734a4b92dcf7a5c51cc4f7424cab67616d0000b273660aadbda2da6b1c2dd3d1a5',
#      'width': 60}],
#    'name': 'Disney',
#    'owner': {'display_name': 'dub!d',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/panda6722'},
#     'href': 'https://api.spotify.com/v1/users/panda6722',
#     'id': 'panda6722',
#     'type': 'user',
#     'uri': 'spotify:user:panda6722'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'MTcxLDI4NDRjMDBiODEwMWUxYjkzYmI3M2M5MjE3ZWMwYmI5NGFlZjMwODQ=',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/3uBDLt5J36QdtVRhjfiQTH/tracks',
#     'total': 54},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:3uBDLt5J36QdtVRhjfiQTH'}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/users/panda6722/playlists?offset=20&limit=20',
#  'offset': 0,
#  'previous': None,
#  'total': 23}
